# %%
import pandas as pd
data10 = pd.read_csv('C:/Users/wojci/Documents/Studia/4 rok/Complex systems/Raport 1/generated_data_files/rest/Ave_L10T10000.txt', 
                   sep=" ", header=None, names=['p','pflow','d','smax','save'])
data50 = pd.read_csv('C:/Users/wojci/Documents/Studia/4 rok/Complex systems/Raport 1/generated_data_files/rest/Ave_L50T10000.txt', 
                   sep=" ", header=None, names=['p','pflow','d','smax','save'])
data100 = pd.read_csv('C:/Users/wojci/Documents/Studia/4 rok/Complex systems/Raport 1/generated_data_files/rest/Ave_L100T10000.txt', 
                   sep=" ", header=None, names=['p','pflow','d','smax','save'])

# %% [markdown]
# ### a) probability pflow

# %%
import matplotlib.pyplot as plt

plt.plot(data10['p'],data10['pflow'],linestyle='--',color="blue")
#plt.scatter(data10['p'],data10['pflow'],marker="o")

plt.plot(data50['p'],data50['pflow'],linestyle=':',color="red")
#plt.scatter(data50['p'],data50['pflow'],marker="*")

plt.plot(data100['p'],data100['pflow'],linestyle='-',color="green")
#plt.scatter(data100['p'],data100['pflow'],marker="^")

plt.xlabel('p')
plt.ylabel('pflow')
plt.title('pflow function of p, T=10000')
plt.legend(["L=10","L=50","L=100"])

a=plt.gcf()
a.savefig("C:/Users/wojci/Documents/Studia/4 rok/Complex systems/Raport 1/pflow.eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### b) average shortest path

# %%
plt.plot(data10['p'],data10['d'],linestyle='--',color="blue")
#plt.scatter(data10['p'],data10['d'])

plt.plot(data50['p'],data50['d'],linestyle=':',color="red")
#plt.scatter(data50['p'],data50['d'])

plt.plot(data100['p'],data100['d'],linestyle='-',color="green")
#plt.scatter(data100['p'],data100['d'])

plt.xlabel('p')
plt.ylabel('d_min')
plt.title('averge shortest path in function of p')
plt.legend(["L=10","L=50","L=100"])


a=plt.gcf()
a.savefig("C:/Users/wojci/Documents/Studia/4 rok/Complex systems/Raport 1/ave_short_path.eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### c) average size of the maximum cluster

# %%
plt.plot(data10['p'],data10['smax'],linestyle='--',color="blue")
#plt.scatter(data10['p'],data10['smax'])

plt.plot(data50['p'],data50['smax'],linestyle=':',color="red")
#plt.scatter(data50['p'],data50['smax'])

plt.plot(data100['p'],data100['smax'],linestyle='-',color="green")
#plt.scatter(data100['p'],data100['smax'])

plt.xlabel('p')
plt.ylabel('smax')
plt.title('Average size of the maximum cluster in function of p')
plt.legend(["L=10","L=50","L=100"])

a=plt.gcf()
a.savefig("C:/Users/wojci/Documents/Studia/4 rok/Complex systems/Raport 1/ave_size_of_max.eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### d) average size of the average cluster

# %%
plt.plot(data10['p'],data10['save'],linestyle='--',color="blue")
#plt.scatter(data10['p'],data10['save'])

plt.plot(data50['p'],data50['save'],linestyle=':',color="red")
#plt.scatter(data50['p'],data50['save'])

plt.plot(data100['p'],data100['save'],linestyle='-',color="green")
#plt.scatter(data100['p'],data100['save'])

plt.xlabel('p')
plt.ylabel('save')
plt.title('Average size of the average cluster in function of p')
a=plt.gcf()
a.savefig("C:/Users/wojci/Documents/Studia/4 rok/Complex systems/Raport 1/ave_size_of_ave.eps")
plt.show()
